# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from settings import PROJECT_PATH

# %%
print(PROJECT_PATH)
# Out:
# /home/lukaszsus/Developer/X_semestr/magisterka/GazeEstimation/

# %%
experiments_file_path = os.path.join(PROJECT_PATH, "experiments_files", "experiments.pickle")
with open(experiments_file_path, 'rb') as file:
    df_results = pickle.load(file)

# %%
df_results.columns
# Out:
# Index(['id', 'name', 'Adam_amsgrad', 'Adam_beta_1', 'Adam_beta_2',
#        'Adam_decay', 'Adam_epsilon', 'Adam_learning_rate', 'Optimizer',
#        'conv_sizes', 'curr_epoch', 'curr_step',
#        'data_set_eye_combination_type', 'data_set_eye_im_size',
#        'data_set_grayscale', 'data_set_headpose_size', 'data_set_input',
#        'data_set_load_function', 'data_set_output', 'data_set_output_size',
#        'data_set_path', 'dense_layers', 'dense_sizes', 'dropout', 'epochs',
#        'learning_rate', 'loss_name', 'model_cls', 'optimizer_name',
#        'person_id', 'sys.gpu.0.free_memory', 'sys.gpu.0.gpu_utilization',
#        'sys.gpu.0.total_memory', 'sys.gpu.0.used_memory', 'test_loss',
#        'test_mae_0', 'test_mae_1', 'test_mean_absolute_error',
#        'test_mean_squared_error', 'train_loss', 'train_mae_0', 'train_mae_1',
#        'train_mean_absolute_error', 'train_mean_squared_error', 'SGD_decay',
#        'SGD_learning_rate', 'SGD_momentum', 'SGD_nesterov',
# ...

# %%
df_best_model = df_results[df_results["name"] == "mpiigaze_both_landmarks_coords"]
df_best_model
# Out:
#                                     id                            name  \
# 3041  883b32760e6d4524b90ba364cb0e4c09  mpiigaze_both_landmarks_coords
# 3042  d7fb09b78b7b4e2484fe21b6c97d9593  mpiigaze_both_landmarks_coords
# 3043  b7e3d4672fed410b8ed660b00bd79aff  mpiigaze_both_landmarks_coords
# 3044  699d642971594e5691b61a5d3bf2b987  mpiigaze_both_landmarks_coords
# 3045  472e57174d594762be87687718d5f728  mpiigaze_both_landmarks_coords
# 3046  223150a144804159a2a8b1602a58aee0  mpiigaze_both_landmarks_coords
# 3047  f6fcff341e1d48f984417b3686e857c0  mpiigaze_both_landmarks_coords
# 3048  959f2930a5ea41fcbd18d8c69fda7847  mpiigaze_both_landmarks_coords
# 3049  cf61d690dd89432e8d6f79c105082a38  mpiigaze_both_landmarks_coords
# 3050  246fe78998d4434cb437f68273b2d94a  mpiigaze_both_landmarks_coords
# 3051  cc2f6c19131746349a5172a8315484c1  mpiigaze_both_landmarks_coords
# 3052  08e4ca480ee24244a3763b34149c7a14  mpiigaze_both_landmarks_coords
# ...

# %%
df_best_model[df_best_model['test_mean_absolute_error'] == df_best_model['test_mean_absolute_error'].min()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     119                 else:
# --> 120                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     121             except Exception:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna, mask)
#     842         else:
# --> 843             result = getattr(values, meth)(axis)
#     844
#
# ~/.local/lib/python3.6/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#
# TypeError: '<=' not supported between instances of 'float' and 'str'
#
# ...

# %%
df_best_model['test_mae_0'] = pd.to_numeric(df_best_model['test_mae_0'])
df_best_model['test_mae_1'] = pd.to_numeric(df_best_model['test_mae_1'])
df_best_model['test_mean_absolute_error'] = pd.to_numeric(df_best_model['test_mean_absolute_error'])
# Out:
# /home/lukaszsus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/lukaszsus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/lukaszsus/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_best_model[df_best_model['test_mean_absolute_error'] == df_best_model['test_mean_absolute_error'].min()]
# Out:
#                                     id                            name  \
# 3058  0bdbffb8359947e4b6fdbfa0adc7bbc7  mpiigaze_both_landmarks_coords
#
#      Adam_amsgrad Adam_beta_1 Adam_beta_2 Adam_decay Adam_epsilon  \
# 3058        false         0.9       0.999        0.0       1.0E-7
#
#      Adam_learning_rate Optimizer  \
# 3058              0.001      Adam
#
#                                              conv_sizes  ...  \
# 3058  [{"n_filters":16,"filter_size":[3,3],"padding"...  ...
#
#      test_angle_error_degrees_2 test_angle_error_degrees_3  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_4 test_angle_error_degrees_5  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_6 test_angle_error_degrees_7  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_8 test_angle_error_degrees_9 use_float64  \
# ...

# %%
df_best_model[df_best_model['test_mae_0'] == df_best_model['test_mae_0'].min()]
# Out:
#                                     id                            name  \
# 3058  0bdbffb8359947e4b6fdbfa0adc7bbc7  mpiigaze_both_landmarks_coords
#
#      Adam_amsgrad Adam_beta_1 Adam_beta_2 Adam_decay Adam_epsilon  \
# 3058        false         0.9       0.999        0.0       1.0E-7
#
#      Adam_learning_rate Optimizer  \
# 3058              0.001      Adam
#
#                                              conv_sizes  ...  \
# 3058  [{"n_filters":16,"filter_size":[3,3],"padding"...  ...
#
#      test_angle_error_degrees_2 test_angle_error_degrees_3  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_4 test_angle_error_degrees_5  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_6 test_angle_error_degrees_7  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_8 test_angle_error_degrees_9 use_float64  \
# ...

# %%
df_best_model[df_best_model['test_mae_1'] == df_best_model['test_mae_1'].min()]
# Out:
#                                     id                            name  \
# 3058  0bdbffb8359947e4b6fdbfa0adc7bbc7  mpiigaze_both_landmarks_coords
#
#      Adam_amsgrad Adam_beta_1 Adam_beta_2 Adam_decay Adam_epsilon  \
# 3058        false         0.9       0.999        0.0       1.0E-7
#
#      Adam_learning_rate Optimizer  \
# 3058              0.001      Adam
#
#                                              conv_sizes  ...  \
# 3058  [{"n_filters":16,"filter_size":[3,3],"padding"...  ...
#
#      test_angle_error_degrees_2 test_angle_error_degrees_3  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_4 test_angle_error_degrees_5  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_6 test_angle_error_degrees_7  \
# 3058                        NaN                        NaN
#
#      test_angle_error_degrees_8 test_angle_error_degrees_9 use_float64  \
# ...

# %% [markdown]
# ## Best params

# %%
params = ['data_set_name', 'epochs', 'optimizer_name', 'learning_rate', 'loss_name', 'conv_sizes', 'dense_sizes']
df_best_model[df_best_model.index == 3058][params].T
# Out:
#                                                              3058
# data_set_name                  mpiigaze_both_landmarks_coords_rgb
# epochs                                                         30
# optimizer_name                                               Adam
# learning_rate                                               0.001
# loss_name                                                     mae
# conv_sizes      [{"n_filters":16,"filter_size":[3,3],"padding"...
# dense_sizes                                           [512,128,2]

# %%
df_best_model[df_best_model.index == 3058]['conv_sizes'].T
