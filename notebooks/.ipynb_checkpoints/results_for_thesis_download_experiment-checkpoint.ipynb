# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from settings import PROJECT_PATH, FOR_THESIS_DIR
import comet_ml
import json

# %% [markdown]
# # Get credentials

# %%
with open(f"{PROJECT_PATH}/data/credentials/comet.json", 'r') as f:
    credentials = json.load(f)

api_key = credentials['api_key']
project_name = credentials['project_name']
workspace = credentials['workspace']

# %%
comet_api = comet_ml.API(rest_api_key=api_key)
# Out:
# COMET WARNING: rest_api_key has been deprecated; please use api_key instead

# %% [markdown]
# # Get one eye experiment data

# %%
exp = comet_api.get("lukaszsus/gaze-estimation/962448d750844c33a32890118dd1e4ab")

# %%
dir(exp)
# Out:
# ['_ATTR_FIELD_MAP',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_check_results',
#  '_get_experiment_url',
#  '_in_jupyter_environment',
#  '_set_from_metadata',
#  '_update_from_metadata',
#  'add_tags',
#  'archive',
#  'archived',
#  'create_symlink',
#  'delete_asset',
#  'display',
#  'download_model',
#  'duration_millis',
#  'end',
#  'end_server_timestamp',
#  'file_name',
#  'file_path',
#  'get_additional_system_info',
#  'get_asset',
#  'get_asset_list',
#  'get_code',
#  'get_command',
#  'get_curves',
#  'get_environment_details',
#  'get_executable',
#  'get_git_metadata',
#  'get_git_patch',
#  'get_gpu_static_info',
#  'get_hostname',
#  'get_html',
#  'get_installed_packages',
#  'get_ip',
#  'get_machine',
#  'get_max_memory',
#  'get_metadata',
#  'get_metrics',
#  'get_metrics_summary',
#  'get_model_asset_list',
#  'get_model_data',
#  'get_model_graph',
#  'get_model_names',
#  'get_name',
#  'get_network_interface_ips',
#  'get_os',
#  'get_os_packages',
#  'get_os_release',
#  'get_os_type',
#  'get_others_summary',
#  'get_output',
#  'get_parameters_summary',
#  'get_pid',
#  'get_processor',
#  'get_python_version',
#  'get_python_version_verbose',
#  'get_system_details',
#  'get_system_metric_names',
#  'get_tags',
#  'get_total_memory',
#  'get_user',
#  'id',
#  'log_additional_system_info',
#  'log_asset',
#  'log_cpu_metrics',
#  'log_curve',
#  'log_gpu_metrics',
#  'log_html',
#  'log_image',
#  'log_load_metrics',
#  'log_metric',
#  'log_other',
#  'log_output',
#  'log_parameter',
#  'log_ram_metrics',
#  'name',
#  'optimization_id',
#  'project_name',
#  'register_model',
#  'set_code',
#  'set_command',
#  'set_end_time',
#  'set_executable',
#  'set_filename',
#  'set_git_metadata',
#  'set_git_patch',
#  'set_gpu_static_info',
#  'set_hostname',
#  'set_installed_packages',
#  'set_ip',
#  'set_machine',
#  'set_model_graph',
#  'set_name',
#  'set_network_interface_ips',
#  'set_os',
#  'set_os_packages',
#  'set_os_release',
#  'set_os_type',
#  'set_pid',
#  'set_processor',
#  'set_python_version',
#  'set_python_version_verbose',
#  'set_start_time',
#  'set_user',
#  'start_server_timestamp',
#  'to_json',
#  'update_status',
#  'url',
#  'workspace']

# %%
df_metrics = pd.DataFrame(exp.get_metrics())

# %%
df_metrics = df_metrics.astype({"metricValue": float, "timestamp": int, "step": float,
                               "epoch": float, "offset": int})

# %% [markdown]
# ### Błąd kątowy w zależności od epoki uczenia

# %%
df_angle_error_degrees = df_metrics[df_metrics["metricName"] == "angle_error_degrees"]
df_angle_error_degrees = df_angle_error_degrees.rename({"metricValue": "Błąd w stopniach", "epoch": "Epoka"}, 
                                                      axis=1)
fig = plt.figure(figsize=(20, 10))
sns.set(style="whitegrid")
ax = sns.lineplot(data=df_angle_error_degrees, y="Błąd w stopniach", x="Epoka")
ax.set_xlabel("Epoka", fontsize=30)
ax.set_ylabel("Błąd w stopniach (test)", fontsize=30)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
plt.savefig(os.path.join(FOR_THESIS_DIR, 'one_eye_p00_angle_error.png'))

# %% [markdown]
# # One eye all together

# %%
exp = comet_api.get("lukaszsus/gaze-estimation/9aefbe8e65e8459c86c4be6f1148bfbf")

# %%
df_params = pd.DataFrame(exp.get_parameters_summary())
df_params
# Out:
#                       name                                           valueMax  \
# 0             Adam_amsgrad                                              false
# 1              Adam_beta_1                                                0.9
# 2              Adam_beta_2                                              0.999
# 3               Adam_decay                                                0.0
# 4             Adam_epsilon                                             1.0E-7
# 5       Adam_learning_rate                                              0.001
# 6               conv_sizes  [{"n_filters":16,"filter_size":[3,3],"padding"...
# 7               curr_epoch                                                 29
# 8                curr_step                                                 29
# 9    data_set_dataset_size                                   3000 per subject
# 10    data_set_eye_im_size                                            [36,60]
# 11      data_set_grayscale                                               true
# 12  data_set_headpose_size                                                  2
# 13          data_set_input                    ["eye_img","headpose_2_angles"]
# 14  data_set_load_function                      partial not JSON serializable
# 15           data_set_name                         mpiigaze_one_eye_grayscale
# 16         data_set_output                                             angles
# 17    data_set_output_size                                                  2
# 18           data_set_path              mpiigaze_processed_one_eye_like_hysts
# 19            dense_layers                                        [512,128,2]
# 20             dense_sizes                                        [512,128,2]
# 21                 dropout                                                0.1
# 22                  epochs                                                 30
# 23           learning_rate                                              0.001
# 24               loss_name                                                mae
# 25               model_cls                                      Modal2ConvNet
# 26               Optimizer                                               Adam
# 27          optimizer_name                                               Adam
# 28               person_id                                               null
# 29             use_float64                                              false
#
#                                              valueMin  \
# 0                                               false
# 1                                                 0.9
# 2                                               0.999
# 3                                                 0.0
# 4                                              1.0E-7
# 5                                               0.001
# 6   [{"n_filters":16,"filter_size":[3,3],"padding"...
# 7                                                  29
# 8                                                  29
# 9                                    3000 per subject
# 10                                            [36,60]
# 11                                               true
# 12                                                  2
# 13                    ["eye_img","headpose_2_angles"]
# 14                      partial not JSON serializable
# 15                         mpiigaze_one_eye_grayscale
# 16                                             angles
# 17                                                  2
# 18              mpiigaze_processed_one_eye_like_hysts
# 19                                        [512,128,2]
# 20                                        [512,128,2]
# 21                                                0.1
# 22                                                 30
# 23                                              0.001
# 24                                                mae
# 25                                      Modal2ConvNet
# 26                                               Adam
# 27                                               Adam
# 28                                               null
# 29                                              false
#
#                                          valueCurrent   timestampMax  \
# 0                                               false  1579452973470
# 1                                                 0.9  1579452973470
# 2                                               0.999  1579452973470
# 3                                                 0.0  1579452973470
# 4                                              1.0E-7  1579452973470
# 5                                               0.001  1579452973470
# 6   [{"n_filters":16,"filter_size":[3,3],"padding"...  1579452973469
# 7                                                  29  1579453028293
# 8                                                  29  1579453028293
# 9                                    3000 per subject  1579452973468
# 10                                            [36,60]  1579452973469
# 11                                               true  1579452973469
# 12                                                  2  1579452973469
# 13                    ["eye_img","headpose_2_angles"]  1579452973468
# 14                      partial not JSON serializable  1579452973469
# 15                         mpiigaze_one_eye_grayscale  1579452973468
# 16                                             angles  1579452973469
# 17                                                  2  1579452973469
# 18              mpiigaze_processed_one_eye_like_hysts  1579452973468
# 19                                        [512,128,2]  1579452973469
# 20                                        [512,128,2]  1579452973469
# 21                                                0.1  1579452973469
# 22                                                 30  1579452973469
# 23                                              0.001  1579452973469
# 24                                                mae  1579452973469
# 25                                      Modal2ConvNet  1579452973469
# 26                                               Adam  1579452973470
# 27                                               Adam  1579452973469
# 28                                               null  1579452973469
# 29                                              false  1579452973469
#
#      timestampMin  timestampCurrent  stepMax  stepMin  stepCurrent
# 0   1579452973470     1579452973470      NaN      NaN          NaN
# 1   1579452973470     1579452973470      NaN      NaN          NaN
# 2   1579452973470     1579452973470      NaN      NaN          NaN
# 3   1579452973470     1579452973470      NaN      NaN          NaN
# 4   1579452973470     1579452973470      NaN      NaN          NaN
# 5   1579452973470     1579452973470      NaN      NaN          NaN
# 6   1579452973469     1579452973469      NaN      NaN          NaN
# 7   1579453028293     1579453028293     28.0     28.0         28.0
# 8   1579453028293     1579453028293     29.0     29.0         29.0
# 9   1579452973468     1579452973468      NaN      NaN          NaN
# 10  1579452973469     1579452973469      NaN      NaN          NaN
# 11  1579452973469     1579452973469      NaN      NaN          NaN
# 12  1579452973469     1579452973469      NaN      NaN          NaN
# 13  1579452973468     1579452973468      NaN      NaN          NaN
# 14  1579452973469     1579452973469      NaN      NaN          NaN
# 15  1579452973468     1579452973468      NaN      NaN          NaN
# 16  1579452973469     1579452973469      NaN      NaN          NaN
# 17  1579452973469     1579452973469      NaN      NaN          NaN
# 18  1579452973468     1579452973468      NaN      NaN          NaN
# 19  1579452973469     1579452973469      NaN      NaN          NaN
# 20  1579452973469     1579452973469      NaN      NaN          NaN
# 21  1579452973469     1579452973469      NaN      NaN          NaN
# 22  1579452973469     1579452973469      NaN      NaN          NaN
# 23  1579452973469     1579452973469      NaN      NaN          NaN
# 24  1579452973469     1579452973469      NaN      NaN          NaN
# 25  1579452973469     1579452973469      NaN      NaN          NaN
# 26  1579452973470     1579452973470      NaN      NaN          NaN
# 27  1579452973469     1579452973469      NaN      NaN          NaN
# 28  1579452973469     1579452973469      NaN      NaN          NaN
# 29  1579452973469     1579452973469      NaN      NaN          NaN

# %%
df_metrics = pd.DataFrame(exp.get_metrics())

# %%
df_metrics["metricName"].unique()
# Out:
# array(['train_mean_squared_error', 'sys.gpu.0.gpu_utilization',
#        'test_loss', 'test_mae_1', 'train_mae_1',
#        'test_mean_absolute_error', 'train_loss',
#        'train_mean_absolute_error', 'test_angle_error_degrees',
#        'sys.gpu.0.total_memory', 'sys.gpu.0.free_memory', 'test_mae_0',
#        'sys.gpu.0.used_memory', 'test_mean_squared_error', 'train_mae_0'],
#       dtype=object)

# %%
df_metrics = df_metrics.astype({"metricValue": float, "timestamp": int, "step": float,
                               "epoch": float, "offset": int})

# %%
df_angle_error_degrees = df_metrics[df_metrics["metricName"] == "test_angle_error_degrees"]
df_angle_error_degrees = df_angle_error_degrees.rename({"metricValue": "Błąd w stopniach", "epoch": "Epoka"}, 
                                                      axis=1)
fig = plt.figure(figsize=(20, 10))
sns.set(style="whitegrid")
ax = sns.lineplot(data=df_angle_error_degrees, y="Błąd w stopniach", x="Epoka")
ax.set_xlabel("Epoka", fontsize=30)
ax.set_ylabel("Błąd w stopniach (test)", fontsize=30)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
plt.savefig(os.path.join(FOR_THESIS_DIR, 'one_eye_all_together_angle_error.png'))

# %%
def bar_plot_per_person(df):
    df = df[["person_id", "test_mean_absolute_error", "angle_error_degrees"]]
    df = df.dropna()
    df = df.astype({"person_id": int, "test_mean_absolute_error": float, "angle_error_degrees": float})
    df = df.groupby(["person_id"]).min()
    df = df.reset_index()
    
    df = df[["person_id", "angle_error_degrees"]]
    df = df.rename({"person_id": "Id osoby", "angle_error_degrees": "Błąd w stopniach"},
                                                        axis=1)
    mean = np.mean(df["Błąd w stopniach"].values)
    df = df.append([{"Id osoby": "średnia", "Błąd w stopniach": mean}], ignore_index=True)
    df = df.round({"Błąd w stopniach": 2})
    
    plt.figure(figsize=(20, 10))
    sns.set(style="whitegrid")
    ax = sns.barplot(x="Id osoby", y="Błąd w stopniach", data=df.iloc[:-1, :])
    ax.set_xlabel("Id osoby", fontsize=30)
    ax.set_ylabel("Błąd w stopniach", fontsize=30)
    ax.tick_params(axis='x', labelsize=20)
    ax.tick_params(axis='y', labelsize=20)
    plt.savefig(os.path.join(FOR_THESIS_DIR, 'one_eye_separately.png'))
    
    return df

# %% [markdown]
# # Both eyes coords

# %%
exp = comet_api.get("lukaszsus/gaze-estimation/5d11c87f245942978cf10187c4b8aef2")

# %%
df_params = pd.DataFrame(exp.get_parameters_summary())
df_params
# Out:
#                       name                                           valueMax  \
# 0             Adam_amsgrad                                              false
# 1              Adam_beta_1                                                0.9
# 2              Adam_beta_2                                              0.999
# 3               Adam_decay                                                0.0
# 4             Adam_epsilon                                             1.0E-7
# 5       Adam_learning_rate                                              0.001
# 6               conv_sizes  [{"n_filters":16,"filter_size":[3,3],"padding"...
# 7               curr_epoch                                                 29
# 8                curr_step                                                 29
# 9    data_set_dataset_size                                   3000 per subject
# 10    data_set_eye_im_size                                            [36,60]
# 11      data_set_grayscale                                              false
# 12  data_set_headpose_size                                                  6
# 13          data_set_input  ["right_eye_img","left_eye_img","headpose_6_an...
# 14  data_set_load_function                      partial not JSON serializable
# 15           data_set_name                 mpiigaze_both_landmarks_coords_rgb
# 16         data_set_output                                             angles
# 17    data_set_output_size                                                  2
# 18           data_set_path                     mpiigaze_both_landmarks_coords
# 19            dense_layers                                        [512,128,2]
# 20             dense_sizes                                        [512,128,2]
# 21                 dropout                                                0.1
# 22                  epochs                                                 30
# 23           learning_rate                                              0.001
# 24               loss_name                                                mae
# 25               model_cls                                      Modal3ConvNet
# 26               Optimizer                                               Adam
# 27          optimizer_name                                               Adam
# 28               person_id                                               null
# 29             use_float64                                              false
#
#                                              valueMin  \
# 0                                               false
# 1                                                 0.9
# 2                                               0.999
# 3                                                 0.0
# 4                                              1.0E-7
# 5                                               0.001
# 6   [{"n_filters":16,"filter_size":[3,3],"padding"...
# 7                                                  29
# 8                                                  29
# 9                                    3000 per subject
# 10                                            [36,60]
# 11                                              false
# 12                                                  6
# 13  ["right_eye_img","left_eye_img","headpose_6_an...
# 14                      partial not JSON serializable
# 15                 mpiigaze_both_landmarks_coords_rgb
# 16                                             angles
# 17                                                  2
# 18                     mpiigaze_both_landmarks_coords
# 19                                        [512,128,2]
# 20                                        [512,128,2]
# 21                                                0.1
# 22                                                 30
# 23                                              0.001
# 24                                                mae
# 25                                      Modal3ConvNet
# 26                                               Adam
# 27                                               Adam
# 28                                               null
# 29                                              false
#
#                                          valueCurrent   timestampMax  \
# 0                                               false  1588611578473
# 1                                                 0.9  1588611578473
# 2                                               0.999  1588611578473
# 3                                                 0.0  1588611578473
# 4                                              1.0E-7  1588611578473
# 5                                               0.001  1588611578473
# 6   [{"n_filters":16,"filter_size":[3,3],"padding"...  1588611578470
# 7                                                  29  1588611702513
# 8                                                  29  1588611702513
# 9                                    3000 per subject  1588611578468
# 10                                            [36,60]  1588611578468
# 11                                              false  1588611578469
# 12                                                  6  1588611578469
# 13  ["right_eye_img","left_eye_img","headpose_6_an...  1588611578468
# 14                      partial not JSON serializable  1588611578469
# 15                 mpiigaze_both_landmarks_coords_rgb  1588611578468
# 16                                             angles  1588611578469
# 17                                                  2  1588611578469
# 18                     mpiigaze_both_landmarks_coords  1588611578468
# 19                                        [512,128,2]  1588611578470
# 20                                        [512,128,2]  1588611578470
# 21                                                0.1  1588611578470
# 22                                                 30  1588611578470
# 23                                              0.001  1588611578470
# 24                                                mae  1588611578471
# 25                                      Modal3ConvNet  1588611578469
# 26                                               Adam  1588611578474
# 27                                               Adam  1588611578470
# 28                                               null  1588611578469
# 29                                              false  1588611578471
#
#      timestampMin  timestampCurrent  stepMax  stepMin  stepCurrent
# 0   1588611578473     1588611578473      NaN      NaN          NaN
# 1   1588611578473     1588611578473      NaN      NaN          NaN
# 2   1588611578473     1588611578473      NaN      NaN          NaN
# 3   1588611578473     1588611578473      NaN      NaN          NaN
# 4   1588611578473     1588611578473      NaN      NaN          NaN
# 5   1588611578473     1588611578473      NaN      NaN          NaN
# 6   1588611578470     1588611578470      NaN      NaN          NaN
# 7   1588611702513     1588611702513     28.0     28.0         28.0
# 8   1588611702513     1588611702513     29.0     29.0         29.0
# 9   1588611578468     1588611578468      NaN      NaN          NaN
# 10  1588611578468     1588611578468      NaN      NaN          NaN
# 11  1588611578469     1588611578469      NaN      NaN          NaN
# 12  1588611578469     1588611578469      NaN      NaN          NaN
# 13  1588611578468     1588611578468      NaN      NaN          NaN
# 14  1588611578469     1588611578469      NaN      NaN          NaN
# 15  1588611578468     1588611578468      NaN      NaN          NaN
# 16  1588611578469     1588611578469      NaN      NaN          NaN
# 17  1588611578469     1588611578469      NaN      NaN          NaN
# 18  1588611578468     1588611578468      NaN      NaN          NaN
# 19  1588611578470     1588611578470      NaN      NaN          NaN
# 20  1588611578470     1588611578470      NaN      NaN          NaN
# 21  1588611578470     1588611578470      NaN      NaN          NaN
# 22  1588611578470     1588611578470      NaN      NaN          NaN
# 23  1588611578470     1588611578470      NaN      NaN          NaN
# 24  1588611578471     1588611578471      NaN      NaN          NaN
# 25  1588611578469     1588611578469      NaN      NaN          NaN
# 26  1588611578474     1588611578474      NaN      NaN          NaN
# 27  1588611578470     1588611578470      NaN      NaN          NaN
# 28  1588611578469     1588611578469      NaN      NaN          NaN
# 29  1588611578471     1588611578471      NaN      NaN          NaN

# %%
conv_sizes = json.loads(df_params.loc[6, "valueMax"])

# %%
conv_sizes
# Out:
# [{'n_filters': 16,
#   'filter_size': [3, 3],
#   'padding': 'valid',
#   'stride': [1, 1],
#   'pool': 'avg',
#   'pool_size': [2, 2],
#   'pool_stride': [2, 2]},
#  {'n_filters': 16,
#   'filter_size': [3, 3],
#   'padding': 'valid',
#   'stride': [1, 1],
#   'pool': None,
#   'pool_size': None,
#   'pool_stride': None},
#  {'n_filters': 16,
#   'filter_size': [3, 3],
#   'padding': 'valid',
#   'stride': [1, 1],
#   'pool': 'avg',
#   'pool_size': [2, 2],
#   'pool_stride': [2, 2]}]

# %% [markdown]
# # Own dataset + mpii gaze

# %%
exp = comet_api.get("lukaszsus/gaze-estimation/c3f1740ed9204251afeff55f0302b5b4")

# %%
exp.get_metrics()
# Out:
# [{'metricName': 'train_mean_squared_error',
#   'metricValue': '0.04934766888618469',
#   'timestamp': 1589925000261,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 74},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.025870203971862793',
#   'timestamp': 1589925004681,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 114},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.02097380720078945',
#   'timestamp': 1589925008827,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 154},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.018016234040260315',
#   'timestamp': 1589925013069,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 194},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.015776073560118675',
#   'timestamp': 1589925016841,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 230},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.014106476679444313',
#   'timestamp': 1589925020597,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 267},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.012642208486795425',
#   'timestamp': 1589925024416,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 305},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.011864649131894112',
#   'timestamp': 1589925028297,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 342},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.010921584442257881',
#   'timestamp': 1589925032098,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 380},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.01015271432697773',
#   'timestamp': 1589925035982,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 418},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.00954886432737112',
#   'timestamp': 1589925039801,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 455},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.009020181372761726',
#   'timestamp': 1589925043730,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 492},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.008833765983581543',
#   'timestamp': 1589925047710,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 530},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.008259636349976063',
#   'timestamp': 1589925051648,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 568},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.007960072718560696',
#   'timestamp': 1589925055504,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 608},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.007611560635268688',
#   'timestamp': 1589925059585,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 647},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.007275128737092018',
#   'timestamp': 1589925063312,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 685},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.00699238246306777',
#   'timestamp': 1589925067113,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 722},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.006664855871349573',
#   'timestamp': 1589925070652,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 758},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.006493168883025646',
#   'timestamp': 1589925074708,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 795},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.006131076719611883',
#   'timestamp': 1589925078703,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 833},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.005899140611290932',
#   'timestamp': 1589925082469,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 870},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.005908861756324768',
#   'timestamp': 1589925086239,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 907},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.00556411175057292',
#   'timestamp': 1589925089985,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 945},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.005672481842339039',
#   'timestamp': 1589925093861,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 981},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.005326622631400824',
#   'timestamp': 1589925097647,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1018},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.005183796864002943',
#   'timestamp': 1589925101408,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1056},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.00514588225632906',
#   'timestamp': 1589925105179,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1092},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004901772830635309',
#   'timestamp': 1589925108964,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1130},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0048609040677547455',
#   'timestamp': 1589925112941,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1166},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004728658124804497',
#   'timestamp': 1589925116961,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1208},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004547290038317442',
#   'timestamp': 1589925120727,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1245},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004464350640773773',
#   'timestamp': 1589925124780,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1281},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0044282893650233746',
#   'timestamp': 1589925128591,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1319},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004242544062435627',
#   'timestamp': 1589925132345,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1355},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0042366692796349525',
#   'timestamp': 1589925136174,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1395},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004077545367181301',
#   'timestamp': 1589925139964,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1432},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.004059456288814545',
#   'timestamp': 1589925143757,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1469},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0040118508040905',
#   'timestamp': 1589925147740,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1508},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.003929256461560726',
#   'timestamp': 1589925151852,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1545},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0037878979928791523',
#   'timestamp': 1589925155745,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1583},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.003792309435084462',
#   'timestamp': 1589925160067,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1625},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0037773519288748503',
#   'timestamp': 1589925164346,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1661},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.003602722194045782',
#   'timestamp': 1589925168364,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1701},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.00357218855060637',
#   'timestamp': 1589925172344,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1739},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.003486895002424717',
#   'timestamp': 1589925176295,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1779},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.003521636361256242',
#   'timestamp': 1589925180259,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1817},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0034153203014284372',
#   'timestamp': 1589925184156,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1855},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0034214905463159084',
#   'timestamp': 1589925188088,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1891},
#  {'metricName': 'train_mean_squared_error',
#   'metricValue': '0.0033472401555627584',
#   'timestamp': 1589925192275,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1931},
#  {'metricName': 'sys.gpu.0.gpu_utilization',
#   'metricValue': '13',
#   'timestamp': 1589924993427,
#   'step': None,
#   'epoch': None,
#   'runContext': None,
#   'offset': 12},
#  {'metricName': 'sys.gpu.0.gpu_utilization',
#   'metricValue': '10',
#   'timestamp': 1589925053491,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 583},
#  {'metricName': 'sys.gpu.0.gpu_utilization',
#   'metricValue': '59',
#   'timestamp': 1589925113552,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1181},
#  {'metricName': 'sys.gpu.0.gpu_utilization',
#   'metricValue': '26',
#   'timestamp': 1589925173613,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1753},
#  {'metricName': 'test_loss',
#   'metricValue': '0.12340313196182251',
#   'timestamp': 1589925000263,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 78},
#  {'metricName': 'test_loss',
#   'metricValue': '0.10193154215812683',
#   'timestamp': 1589925004683,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 117},
#  {'metricName': 'test_loss',
#   'metricValue': '0.09161601960659027',
#   'timestamp': 1589925008829,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 157},
#  {'metricName': 'test_loss',
#   'metricValue': '0.09527059644460678',
#   'timestamp': 1589925013070,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 197},
#  {'metricName': 'test_loss',
#   'metricValue': '0.08134905248880386',
#   'timestamp': 1589925016843,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 234},
#  {'metricName': 'test_loss',
#   'metricValue': '0.0869024321436882',
#   'timestamp': 1589925020599,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 271},
#  {'metricName': 'test_loss',
#   'metricValue': '0.07349306344985962',
#   'timestamp': 1589925024417,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 308},
#  {'metricName': 'test_loss',
#   'metricValue': '0.077253557741642',
#   'timestamp': 1589925028299,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 346},
#  {'metricName': 'test_loss',
#   'metricValue': '0.07131972908973694',
#   'timestamp': 1589925032100,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 383},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06845124065876007',
#   'timestamp': 1589925035983,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 421},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06607118248939514',
#   'timestamp': 1589925039802,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 458},
#  {'metricName': 'test_loss',
#   'metricValue': '0.0656960979104042',
#   'timestamp': 1589925043731,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 495},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06490274518728256',
#   'timestamp': 1589925047712,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 533},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06282653659582138',
#   'timestamp': 1589925051649,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 571},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06166093423962593',
#   'timestamp': 1589925055505,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 611},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06440471857786179',
#   'timestamp': 1589925059587,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 651},
#  {'metricName': 'test_loss',
#   'metricValue': '0.062399085611104965',
#   'timestamp': 1589925063313,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 688},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06358330696821213',
#   'timestamp': 1589925067114,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 725},
#  {'metricName': 'test_loss',
#   'metricValue': '0.060927581042051315',
#   'timestamp': 1589925070653,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 762},
#  {'metricName': 'test_loss',
#   'metricValue': '0.060626816004514694',
#   'timestamp': 1589925074709,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 799},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05819853022694588',
#   'timestamp': 1589925078704,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 836},
#  {'metricName': 'test_loss',
#   'metricValue': '0.058866966515779495',
#   'timestamp': 1589925082470,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 873},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05830831080675125',
#   'timestamp': 1589925086240,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 911},
#  {'metricName': 'test_loss',
#   'metricValue': '0.06746895611286163',
#   'timestamp': 1589925089987,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 948},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05724117159843445',
#   'timestamp': 1589925093863,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 985},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05791063979268074',
#   'timestamp': 1589925097648,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1022},
#  {'metricName': 'test_loss',
#   'metricValue': '0.058966249227523804',
#   'timestamp': 1589925101409,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1059},
#  {'metricName': 'test_loss',
#   'metricValue': '0.058356549590826035',
#   'timestamp': 1589925105181,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1095},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05672948807477951',
#   'timestamp': 1589925108965,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1133},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05632086098194122',
#   'timestamp': 1589925112942,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1170},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05634796991944313',
#   'timestamp': 1589925116963,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1211},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05684838071465492',
#   'timestamp': 1589925120729,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1248},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05597458407282829',
#   'timestamp': 1589925124782,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1285},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05537637695670128',
#   'timestamp': 1589925128593,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1322},
#  {'metricName': 'test_loss',
#   'metricValue': '0.055174749344587326',
#   'timestamp': 1589925132346,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1359},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05556351691484451',
#   'timestamp': 1589925136175,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1398},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05558056756854057',
#   'timestamp': 1589925139966,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1436},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05775640904903412',
#   'timestamp': 1589925143758,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1473},
#  {'metricName': 'test_loss',
#   'metricValue': '0.055874720215797424',
#   'timestamp': 1589925147742,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1512},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05496087670326233',
#   'timestamp': 1589925151853,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1548},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05374602600932121',
#   'timestamp': 1589925155747,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1587},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05587874352931976',
#   'timestamp': 1589925160069,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1628},
#  {'metricName': 'test_loss',
#   'metricValue': '0.053704291582107544',
#   'timestamp': 1589925164347,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1665},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05416853725910187',
#   'timestamp': 1589925168365,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1704},
#  {'metricName': 'test_loss',
#   'metricValue': '0.057119220495224',
#   'timestamp': 1589925172345,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1742},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05333656445145607',
#   'timestamp': 1589925176296,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1782},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05406880006194115',
#   'timestamp': 1589925180261,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1820},
#  {'metricName': 'test_loss',
#   'metricValue': '0.05413997918367386',
#   'timestamp': 1589925184157,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1858},
#  {'metricName': 'test_loss',
#   'metricValue': '0.053352177143096924',
#   'timestamp': 1589925188090,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1895},
#  {'metricName': 'test_loss',
#   'metricValue': '0.054624300450086594',
#   'timestamp': 1589925192276,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1934},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.0932093933224678',
#   'timestamp': 1589925000265,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 82},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.07868693768978119',
#   'timestamp': 1589925004685,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 121},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.06977423280477524',
#   'timestamp': 1589925008831,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 161},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.06903089582920074',
#   'timestamp': 1589925013072,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 201},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.06536957621574402',
#   'timestamp': 1589925016844,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 238},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.062231261283159256',
#   'timestamp': 1589925020600,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 275},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05975811555981636',
#   'timestamp': 1589925024420,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 312},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05620093643665314',
#   'timestamp': 1589925028301,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 350},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05884310603141785',
#   'timestamp': 1589925032102,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 387},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.057325057685375214',
#   'timestamp': 1589925035985,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 425},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05263368412852287',
#   'timestamp': 1589925039805,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 462},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05226951092481613',
#   'timestamp': 1589925043734,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 499},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05341339856386185',
#   'timestamp': 1589925047714,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 537},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.050806134939193726',
#   'timestamp': 1589925051651,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 575},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05017312616109848',
#   'timestamp': 1589925055507,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 615},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05359868332743645',
#   'timestamp': 1589925059589,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 655},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.052582938224077225',
#   'timestamp': 1589925063315,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 692},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05205802991986275',
#   'timestamp': 1589925067117,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 729},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.049170032143592834',
#   'timestamp': 1589925070655,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 766},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04991934075951576',
#   'timestamp': 1589925074712,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 803},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04720204323530197',
#   'timestamp': 1589925078706,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 840},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.049602918326854706',
#   'timestamp': 1589925082472,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 877},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04708859696984291',
#   'timestamp': 1589925086243,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 915},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05421724170446396',
#   'timestamp': 1589925089989,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 952},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04680658131837845',
#   'timestamp': 1589925093865,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 989},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.047417450696229935',
#   'timestamp': 1589925097650,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1026},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04672279953956604',
#   'timestamp': 1589925101411,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1063},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.05066099390387535',
#   'timestamp': 1589925105183,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1100},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04614962264895439',
#   'timestamp': 1589925108967,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1137},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04553968459367752',
#   'timestamp': 1589925112944,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1174},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04576318338513374',
#   'timestamp': 1589925116965,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1215},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.045906584709882736',
#   'timestamp': 1589925120731,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1252},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04759605973958969',
#   'timestamp': 1589925124784,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1289},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04543192312121391',
#   'timestamp': 1589925128595,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1326},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04525931924581528',
#   'timestamp': 1589925132348,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1363},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.044212616980075836',
#   'timestamp': 1589925136177,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1402},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04557206854224205',
#   'timestamp': 1589925139968,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1440},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04902837425470352',
#   'timestamp': 1589925143760,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1477},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04632116109132767',
#   'timestamp': 1589925147745,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1516},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04601607471704483',
#   'timestamp': 1589925151856,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1553},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.044097188860177994',
#   'timestamp': 1589925155750,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1591},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04453308507800102',
#   'timestamp': 1589925160071,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1632},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.043577421456575394',
#   'timestamp': 1589925164349,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1669},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04361714422702789',
#   'timestamp': 1589925168368,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1708},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04539259150624275',
#   'timestamp': 1589925172347,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1746},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04417889192700386',
#   'timestamp': 1589925176298,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1786},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04403930529952049',
#   'timestamp': 1589925180263,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1824},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.04400520399212837',
#   'timestamp': 1589925184160,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1862},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.044194094836711884',
#   'timestamp': 1589925188093,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1899},
#  {'metricName': 'test_mae_1',
#   'metricValue': '0.045272983610630035',
#   'timestamp': 1589925192278,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1938},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.1513305902481079',
#   'timestamp': 1589925000262,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 77},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.09507331252098083',
#   'timestamp': 1589925004682,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 116},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.08258958160877228',
#   'timestamp': 1589925008829,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 156},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.07766465842723846',
#   'timestamp': 1589925013070,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 196},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.07214021682739258',
#   'timestamp': 1589925016842,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 233},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.0693918839097023',
#   'timestamp': 1589925020598,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 270},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.06502009183168411',
#   'timestamp': 1589925024417,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 307},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.06395380198955536',
#   'timestamp': 1589925028298,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 345},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.060774222016334534',
#   'timestamp': 1589925032099,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 382},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.05901501700282097',
#   'timestamp': 1589925035983,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 420},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.05710624158382416',
#   'timestamp': 1589925039802,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 457},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.056528933346271515',
#   'timestamp': 1589925043731,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 494},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.055410418659448624',
#   'timestamp': 1589925047712,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 532},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.05430212616920471',
#   'timestamp': 1589925051649,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 570},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.05271511897444725',
#   'timestamp': 1589925055505,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 610},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.05297569930553436',
#   'timestamp': 1589925059587,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 650},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.051152050495147705',
#   'timestamp': 1589925063313,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 687},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.051293324679136276',
#   'timestamp': 1589925067114,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 724},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.049210626631975174',
#   'timestamp': 1589925070653,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 761},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.048198726028203964',
#   'timestamp': 1589925074709,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 798},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04742412641644478',
#   'timestamp': 1589925078704,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 835},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04663790017366409',
#   'timestamp': 1589925082470,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 872},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04670814052224159',
#   'timestamp': 1589925086240,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 910},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04543551802635193',
#   'timestamp': 1589925089986,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 947},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.045714255422353745',
#   'timestamp': 1589925093862,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 983},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.044112253934144974',
#   'timestamp': 1589925097648,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1021},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04401428997516632',
#   'timestamp': 1589925101409,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1058},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04447529837489128',
#   'timestamp': 1589925105180,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1094},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04301641881465912',
#   'timestamp': 1589925108965,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1132},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04270131140947342',
#   'timestamp': 1589925112942,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1168},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04200180992484093',
#   'timestamp': 1589925116962,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1210},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04140390083193779',
#   'timestamp': 1589925120728,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1247},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04093288257718086',
#   'timestamp': 1589925124781,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1283},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04137040302157402',
#   'timestamp': 1589925128592,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1321},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.04094027727842331',
#   'timestamp': 1589925132346,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1358},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.040031783282756805',
#   'timestamp': 1589925136175,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1397},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03993630036711693',
#   'timestamp': 1589925139965,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1435},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03966130316257477',
#   'timestamp': 1589925143758,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1471},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.039265505969524384',
#   'timestamp': 1589925147742,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1511},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.039165712893009186',
#   'timestamp': 1589925151853,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1547},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03818880394101143',
#   'timestamp': 1589925155747,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1586},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03859435021877289',
#   'timestamp': 1589925160068,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1627},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.038739919662475586',
#   'timestamp': 1589925164347,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1664},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03763085976243019',
#   'timestamp': 1589925168365,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1703},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03772488236427307',
#   'timestamp': 1589925172345,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1741},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.036913108080625534',
#   'timestamp': 1589925176296,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1781},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.0368507094681263',
#   'timestamp': 1589925180260,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1819},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03693403676152229',
#   'timestamp': 1589925184157,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1857},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.03648151084780693',
#   'timestamp': 1589925188090,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1894},
#  {'metricName': 'train_mae_1',
#   'metricValue': '0.037070728838443756',
#   'timestamp': 1589925192276,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1933},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.12340313196182251',
#   'timestamp': 1589925000263,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 79},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.10193154215812683',
#   'timestamp': 1589925004683,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 118},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.09161601960659027',
#   'timestamp': 1589925008829,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 158},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.09527059644460678',
#   'timestamp': 1589925013071,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 198},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.08134905248880386',
#   'timestamp': 1589925016843,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 235},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.0869024321436882',
#   'timestamp': 1589925020599,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 272},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.07349306344985962',
#   'timestamp': 1589925024418,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 309},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.077253557741642',
#   'timestamp': 1589925028299,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 347},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.07131972908973694',
#   'timestamp': 1589925032100,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 384},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06845124065876007',
#   'timestamp': 1589925035984,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 422},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06607118248939514',
#   'timestamp': 1589925039803,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 459},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.0656960979104042',
#   'timestamp': 1589925043732,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 496},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06490274518728256',
#   'timestamp': 1589925047713,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 534},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06282653659582138',
#   'timestamp': 1589925051650,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 572},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06166093423962593',
#   'timestamp': 1589925055506,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 612},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06440471857786179',
#   'timestamp': 1589925059587,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 652},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.062399085611104965',
#   'timestamp': 1589925063313,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 689},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06358330696821213',
#   'timestamp': 1589925067115,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 726},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.060927581042051315',
#   'timestamp': 1589925070654,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 763},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.060626816004514694',
#   'timestamp': 1589925074710,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 800},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05819853022694588',
#   'timestamp': 1589925078705,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 837},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.058866966515779495',
#   'timestamp': 1589925082470,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 874},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05830831080675125',
#   'timestamp': 1589925086241,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 912},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.06746895611286163',
#   'timestamp': 1589925089987,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 949},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05724117159843445',
#   'timestamp': 1589925093863,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 986},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05791063979268074',
#   'timestamp': 1589925097649,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1023},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.058966249227523804',
#   'timestamp': 1589925101410,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1060},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.058356549590826035',
#   'timestamp': 1589925105181,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1097},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05672948807477951',
#   'timestamp': 1589925108965,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1134},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05632086098194122',
#   'timestamp': 1589925112943,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1171},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05634796991944313',
#   'timestamp': 1589925116963,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1212},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05684838071465492',
#   'timestamp': 1589925120729,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1249},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05597458407282829',
#   'timestamp': 1589925124782,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1286},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05537637695670128',
#   'timestamp': 1589925128593,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1323},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.055174749344587326',
#   'timestamp': 1589925132347,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1360},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05556351691484451',
#   'timestamp': 1589925136176,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1399},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05558056756854057',
#   'timestamp': 1589925139966,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1437},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05775640904903412',
#   'timestamp': 1589925143759,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1474},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.055874720215797424',
#   'timestamp': 1589925147743,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1513},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05496087670326233',
#   'timestamp': 1589925151854,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1550},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05374602600932121',
#   'timestamp': 1589925155748,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1588},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05587874352931976',
#   'timestamp': 1589925160069,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1629},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.053704291582107544',
#   'timestamp': 1589925164348,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1666},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05416853725910187',
#   'timestamp': 1589925168366,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1705},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.057119220495224',
#   'timestamp': 1589925172346,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1743},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05333656445145607',
#   'timestamp': 1589925176297,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1783},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05406880006194115',
#   'timestamp': 1589925180261,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1821},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.05413997918367386',
#   'timestamp': 1589925184158,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1859},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.053352177143096924',
#   'timestamp': 1589925188091,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1896},
#  {'metricName': 'test_mean_absolute_error',
#   'metricValue': '0.054624300450086594',
#   'timestamp': 1589925192277,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1935},
#  {'metricName': 'train_loss',
#   'metricValue': '0.17156045138835907',
#   'timestamp': 1589925000260,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 72},
#  {'metricName': 'train_loss',
#   'metricValue': '0.11822737753391266',
#   'timestamp': 1589925004680,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 111},
#  {'metricName': 'train_loss',
#   'metricValue': '0.10477001219987869',
#   'timestamp': 1589925008826,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 151},
#  {'metricName': 'train_loss',
#   'metricValue': '0.09635870158672333',
#   'timestamp': 1589925013067,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 191},
#  {'metricName': 'train_loss',
#   'metricValue': '0.08971517533063889',
#   'timestamp': 1589925016840,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 228},
#  {'metricName': 'train_loss',
#   'metricValue': '0.08447246253490448',
#   'timestamp': 1589925020596,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 265},
#  {'metricName': 'train_loss',
#   'metricValue': '0.07965748012065887',
#   'timestamp': 1589925024415,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 302},
#  {'metricName': 'train_loss',
#   'metricValue': '0.07723995298147202',
#   'timestamp': 1589925028296,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 340},
#  {'metricName': 'train_loss',
#   'metricValue': '0.0739276334643364',
#   'timestamp': 1589925032097,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 377},
#  {'metricName': 'train_loss',
#   'metricValue': '0.07111000269651413',
#   'timestamp': 1589925035980,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 416},
#  {'metricName': 'train_loss',
#   'metricValue': '0.0690106600522995',
#   'timestamp': 1589925039800,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 452},
#  {'metricName': 'train_loss',
#   'metricValue': '0.06722142547369003',
#   'timestamp': 1589925043729,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 489},
#  {'metricName': 'train_loss',
#   'metricValue': '0.06657577306032181',
#   'timestamp': 1589925047709,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 527},
#  {'metricName': 'train_loss',
#   'metricValue': '0.06424356997013092',
#   'timestamp': 1589925051647,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 565},
#  {'metricName': 'train_loss',
#   'metricValue': '0.0632653683423996',
#   'timestamp': 1589925055502,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 605},
#  {'metricName': 'train_loss',
#   'metricValue': '0.06219814345240593',
#   'timestamp': 1589925059584,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 645},
#  {'metricName': 'train_loss',
#   'metricValue': '0.06053561717271805',
#   'timestamp': 1589925063310,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 682},
#  {'metricName': 'train_loss',
#   'metricValue': '0.05950269475579262',
#   'timestamp': 1589925067112,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 719},
#  {'metricName': 'train_loss',
#   'metricValue': '0.0581965409219265',
#   'timestamp': 1589925070651,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 756},
#  {'metricName': 'train_loss',
#   'metricValue': '0.05714502930641174',
#   'timestamp': 1589925074707,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 793},
#  {'metricName': 'train_loss',
#   'metricValue': '0.05584714934229851',
#   'timestamp': 1589925078702,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 830},
#  {'metricName': 'train_loss',
# ...
#   'metricValue': '0.01025522779673338',
#   'timestamp': 1589925035984,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 423},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.009927685372531414',
#   'timestamp': 1589925039803,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 460},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.009598962031304836',
#   'timestamp': 1589925043732,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 497},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.009394646622240543',
#   'timestamp': 1589925047713,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 535},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008877926506102085',
#   'timestamp': 1589925051650,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 573},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.00882489699870348',
#   'timestamp': 1589925055506,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 613},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.009008234366774559',
#   'timestamp': 1589925059588,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 653},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008679335936903954',
#   'timestamp': 1589925063314,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 690},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008893863297998905',
#   'timestamp': 1589925067115,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 727},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008491420187056065',
#   'timestamp': 1589925070654,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 764},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008412639610469341',
#   'timestamp': 1589925074711,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 801},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008056296966969967',
#   'timestamp': 1589925078705,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 838},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008034107275307178',
#   'timestamp': 1589925082471,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 875},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.00795222632586956',
#   'timestamp': 1589925086241,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 913},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.009890677407383919',
#   'timestamp': 1589925089988,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 950},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.00773762259632349',
#   'timestamp': 1589925093864,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 987},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007917498238384724',
#   'timestamp': 1589925097649,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1024},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.008001148700714111',
#   'timestamp': 1589925101410,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1061},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.00770945567637682',
#   'timestamp': 1589925105182,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1098},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007491277996450663',
#   'timestamp': 1589925108966,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1135},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007520569954067469',
#   'timestamp': 1589925112943,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1172},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007513924036175013',
#   'timestamp': 1589925116964,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1213},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007532176561653614',
#   'timestamp': 1589925120730,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1250},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007295822259038687',
#   'timestamp': 1589925124783,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1287},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007463391870260239',
#   'timestamp': 1589925128594,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1324},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007414325140416622',
#   'timestamp': 1589925132347,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1361},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.00752339418977499',
#   'timestamp': 1589925136176,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1400},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007425966672599316',
#   'timestamp': 1589925139967,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1438},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007756897713989019',
#   'timestamp': 1589925143759,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1475},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007258382625877857',
#   'timestamp': 1589925147744,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1514},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007246619090437889',
#   'timestamp': 1589925151855,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1551},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007061181124299765',
#   'timestamp': 1589925155749,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1589},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007507683243602514',
#   'timestamp': 1589925160070,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1630},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007039273157715797',
#   'timestamp': 1589925164348,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1667},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007161357440054417',
#   'timestamp': 1589925168367,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1706},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.0075883325189352036',
#   'timestamp': 1589925172346,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1744},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007014347240328789',
#   'timestamp': 1589925176297,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1784},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007089994382113218',
#   'timestamp': 1589925180262,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1822},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.0070340330712497234',
#   'timestamp': 1589925184159,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1860},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.006959361955523491',
#   'timestamp': 1589925188092,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1897},
#  {'metricName': 'test_mean_squared_error',
#   'metricValue': '0.007008651737123728',
#   'timestamp': 1589925192277,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1936},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.19174976646900177',
#   'timestamp': 1589925000262,
#   'step': 0,
#   'epoch': 0,
#   'runContext': None,
#   'offset': 76},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.14138509333133698',
#   'timestamp': 1589925004682,
#   'step': 1,
#   'epoch': 1,
#   'runContext': None,
#   'offset': 115},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.12692782282829285',
#   'timestamp': 1589925008828,
#   'step': 2,
#   'epoch': 2,
#   'runContext': None,
#   'offset': 155},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.11503539234399796',
#   'timestamp': 1589925013069,
#   'step': 3,
#   'epoch': 3,
#   'runContext': None,
#   'offset': 195},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.10728767514228821',
#   'timestamp': 1589925016841,
#   'step': 4,
#   'epoch': 4,
#   'runContext': None,
#   'offset': 231},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.09955907613039017',
#   'timestamp': 1589925020597,
#   'step': 5,
#   'epoch': 5,
#   'runContext': None,
#   'offset': 268},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.09429865330457687',
#   'timestamp': 1589925024417,
#   'step': 6,
#   'epoch': 6,
#   'runContext': None,
#   'offset': 306},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.0905279740691185',
#   'timestamp': 1589925028298,
#   'step': 7,
#   'epoch': 7,
#   'runContext': None,
#   'offset': 344},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.08707716315984726',
#   'timestamp': 1589925032099,
#   'step': 8,
#   'epoch': 8,
#   'runContext': None,
#   'offset': 381},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.08319288492202759',
#   'timestamp': 1589925035982,
#   'step': 9,
#   'epoch': 9,
#   'runContext': None,
#   'offset': 419},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.08091066032648087',
#   'timestamp': 1589925039802,
#   'step': 10,
#   'epoch': 10,
#   'runContext': None,
#   'offset': 456},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.07791593670845032',
#   'timestamp': 1589925043731,
#   'step': 11,
#   'epoch': 11,
#   'runContext': None,
#   'offset': 493},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.07773660868406296',
#   'timestamp': 1589925047711,
#   'step': 12,
#   'epoch': 12,
#   'runContext': None,
#   'offset': 531},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.07418576627969742',
#   'timestamp': 1589925051648,
#   'step': 13,
#   'epoch': 13,
#   'runContext': None,
#   'offset': 569},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.0738154873251915',
#   'timestamp': 1589925055504,
#   'step': 14,
#   'epoch': 14,
#   'runContext': None,
#   'offset': 609},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.07141350209712982',
#   'timestamp': 1589925059586,
#   'step': 15,
#   'epoch': 15,
#   'runContext': None,
#   'offset': 649},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06992582976818085',
#   'timestamp': 1589925063312,
#   'step': 16,
#   'epoch': 16,
#   'runContext': None,
#   'offset': 686},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.0677114725112915',
#   'timestamp': 1589925067114,
#   'step': 17,
#   'epoch': 17,
#   'runContext': None,
#   'offset': 723},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06718070805072784',
#   'timestamp': 1589925070652,
#   'step': 18,
#   'epoch': 18,
#   'runContext': None,
#   'offset': 760},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06608874350786209',
#   'timestamp': 1589925074708,
#   'step': 19,
#   'epoch': 19,
#   'runContext': None,
#   'offset': 797},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06427022814750671',
#   'timestamp': 1589925078703,
#   'step': 20,
#   'epoch': 20,
#   'runContext': None,
#   'offset': 834},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06277800351381302',
#   'timestamp': 1589925082469,
#   'step': 21,
#   'epoch': 21,
#   'runContext': None,
#   'offset': 871},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06292884051799774',
#   'timestamp': 1589925086239,
#   'step': 22,
#   'epoch': 22,
#   'runContext': None,
#   'offset': 908},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06103367730975151',
#   'timestamp': 1589925089986,
#   'step': 23,
#   'epoch': 23,
#   'runContext': None,
#   'offset': 946},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06213456392288208',
#   'timestamp': 1589925093861,
#   'step': 24,
#   'epoch': 24,
#   'runContext': None,
#   'offset': 982},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.06023178994655609',
#   'timestamp': 1589925097647,
#   'step': 25,
#   'epoch': 25,
#   'runContext': None,
#   'offset': 1019},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.059265632182359695',
#   'timestamp': 1589925101409,
#   'step': 26,
#   'epoch': 26,
#   'runContext': None,
#   'offset': 1057},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.058748383074998856',
#   'timestamp': 1589925105179,
#   'step': 27,
#   'epoch': 27,
#   'runContext': None,
#   'offset': 1093},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.057742856442928314',
#   'timestamp': 1589925108964,
#   'step': 28,
#   'epoch': 28,
#   'runContext': None,
#   'offset': 1131},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05750441178679466',
#   'timestamp': 1589925112941,
#   'step': 29,
#   'epoch': 29,
#   'runContext': None,
#   'offset': 1167},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05691025033593178',
#   'timestamp': 1589925116962,
#   'step': 30,
#   'epoch': 30,
#   'runContext': None,
#   'offset': 1209},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.055762793868780136',
#   'timestamp': 1589925120728,
#   'step': 31,
#   'epoch': 31,
#   'runContext': None,
#   'offset': 1246},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.0550425723195076',
#   'timestamp': 1589925124781,
#   'step': 32,
#   'epoch': 32,
#   'runContext': None,
#   'offset': 1282},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.055055297911167145',
#   'timestamp': 1589925128592,
#   'step': 33,
#   'epoch': 33,
#   'runContext': None,
#   'offset': 1320},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05306907370686531',
#   'timestamp': 1589925132345,
#   'step': 34,
#   'epoch': 34,
#   'runContext': None,
#   'offset': 1356},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05398471653461456',
#   'timestamp': 1589925136174,
#   'step': 35,
#   'epoch': 35,
#   'runContext': None,
#   'offset': 1396},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05220068246126175',
#   'timestamp': 1589925139964,
#   'step': 36,
#   'epoch': 36,
#   'runContext': None,
#   'offset': 1434},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05225873365998268',
#   'timestamp': 1589925143757,
#   'step': 37,
#   'epoch': 37,
#   'runContext': None,
#   'offset': 1470},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05226946249604225',
#   'timestamp': 1589925147741,
#   'step': 38,
#   'epoch': 38,
#   'runContext': None,
#   'offset': 1510},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.051763154566287994',
#   'timestamp': 1589925151852,
#   'step': 39,
#   'epoch': 39,
#   'runContext': None,
#   'offset': 1546},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.050696562975645065',
#   'timestamp': 1589925155746,
#   'step': 40,
#   'epoch': 40,
#   'runContext': None,
#   'offset': 1584},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.050607830286026',
#   'timestamp': 1589925160068,
#   'step': 41,
#   'epoch': 41,
#   'runContext': None,
#   'offset': 1626},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.05084586888551712',
#   'timestamp': 1589925164346,
#   'step': 42,
#   'epoch': 42,
#   'runContext': None,
#   'offset': 1663},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.04942895472049713',
#   'timestamp': 1589925168364,
#   'step': 43,
#   'epoch': 43,
#   'runContext': None,
#   'offset': 1702},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.04932421073317528',
#   'timestamp': 1589925172344,
#   'step': 44,
#   'epoch': 44,
#   'runContext': None,
#   'offset': 1740},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.048910293728113174',
#   'timestamp': 1589925176295,
#   'step': 45,
#   'epoch': 45,
#   'runContext': None,
#   'offset': 1780},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.04913250356912613',
#   'timestamp': 1589925180260,
#   'step': 46,
#   'epoch': 46,
#   'runContext': None,
#   'offset': 1818},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.04778429865837097',
#   'timestamp': 1589925184156,
#   'step': 47,
#   'epoch': 47,
#   'runContext': None,
#   'offset': 1856},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.04884875938296318',
#   'timestamp': 1589925188089,
#   'step': 48,
#   'epoch': 48,
#   'runContext': None,
#   'offset': 1893},
#  {'metricName': 'train_mae_0',
#   'metricValue': '0.04739775136113167',
#   'timestamp': 1589925192275,
#   'step': 49,
#   'epoch': 49,
#   'runContext': None,
#   'offset': 1932}]

# %%
exp.name
# Out:
# 'own_dataset_mpii_gaze'

# %% [markdown]
# # For thesis

# %% [markdown]
# # First trial - MPII Gaze + one person from own dataset

# %%
url = "lukaszsus/gaze-estimation/9065d73b0a9f45c9af35c9c08e31878d"

# %%
exp = comet_api.get(url)

# %%
df_metrics_exp = pd.DataFrame(exp.get_metrics_summary())

# %%
df_metrics_exp
# Out:
#                          name              valueMax               valueMin  \
# 0       forward_pass_time_gpu  0.008713061809539796   0.008713061809539796
# 1       sys.gpu.0.free_memory         5.161811968E9           4.10714112E9
# 2   sys.gpu.0.gpu_utilization                  98.0                    1.0
# 3      sys.gpu.0.total_memory         6.233391104E9          6.233391104E9
# 4       sys.gpu.0.used_memory         2.126249984E9          1.071579136E9
# 5    test_angle_error_degrees    10.755831718444824      6.065732955932617
# 6                   test_loss    0.1296808272600174    0.07214269042015076
# 7                  test_mae_0    0.1565936654806137    0.08275546878576279
# 8                  test_mae_1   0.10258214175701141    0.06109204143285751
# 9           test_mae_person_0   0.04974875599145889    0.04974875599145889
# 10          test_mae_person_1  0.058915458619594574   0.058915458619594574
# 11         test_mae_person_10   0.06281230598688126    0.06281230598688126
# 12         test_mae_person_11   0.05576547980308533    0.05576547980308533
# 13         test_mae_person_12    0.0715394914150238     0.0715394914150238
# 14         test_mae_person_13   0.06764839589595795    0.06764839589595795
# 15         test_mae_person_14  0.039921440184116364   0.039921440184116364
# 16          test_mae_person_2   0.04917605221271515    0.04917605221271515
# 17         test_mae_person_24    0.1507585346698761     0.1507585346698761
# 18         test_mae_person_25   0.13526707887649536    0.13526707887649536
# 19          test_mae_person_3    0.0684451013803482     0.0684451013803482
# 20          test_mae_person_4   0.05174454301595688    0.05174454301595688
# 21          test_mae_person_5  0.052967652678489685   0.052967652678489685
# 22          test_mae_person_6  0.060321394354104996   0.060321394354104996
# 23          test_mae_person_8   0.08679430186748505    0.08679430186748505
# 24          test_mae_person_9   0.07398368418216705    0.07398368418216705
# 25   test_mean_absolute_error    0.1296808272600174    0.07214269042015076
# 26    test_mean_squared_error     0.030699597671628   0.012836082838475704
# 27                 train_loss    0.1596747487783432    0.03789356350898743
# 28                train_mae_0     0.181523859500885    0.04093693196773529
# 29                train_mae_1    0.1378157138824463    0.03465631976723671
# 30  train_mean_absolute_error    0.1596747487783432    0.03789356350898743
# 31   train_mean_squared_error   0.04376230388879776  0.0028981200885027647
#
#              valueCurrent   timestampMax   timestampMin  timestampCurrent  \
# 0    0.008713061809539796  1590184045276  1590184045276     1590184045276
# 1           4.116185088E9  1590183629713  1590183629713     1590183990083
# 2                    62.0  1590183629713  1590183629713     1590183990083
# 3           6.233391104E9  1590183629711  1590183629711     1590183629711
# 4           2.117206016E9  1590183629713  1590183629713     1590183990083
# 5       6.175627708435059  1590183637753  1590183637753     1590184043416
# 6     0.07336408644914627  1590183636992  1590183636992     1590184042687
# 7     0.08433517068624496  1590183636994  1590183636994     1590184042689
# 8     0.06227791681885719  1590183636995  1590183636995     1590184042690
# 9     0.04974875599145889  1590184045237  1590184045237     1590184045237
# 10   0.058915458619594574  1590184045240  1590184045240     1590184045240
# 11    0.06281230598688126  1590184045261  1590184045261     1590184045261
# 12    0.05576547980308533  1590184045263  1590184045263     1590184045263
# 13     0.0715394914150238  1590184045266  1590184045266     1590184045266
# 14    0.06764839589595795  1590184045268  1590184045268     1590184045268
# 15   0.039921440184116364  1590184045271  1590184045271     1590184045271
# 16    0.04917605221271515  1590184045243  1590184045243     1590184045243
# 17     0.1507585346698761  1590184045274  1590184045274     1590184045274
# 18    0.13526707887649536  1590184045276  1590184045276     1590184045276
# 19     0.0684451013803482  1590184045245  1590184045245     1590184045245
# 20    0.05174454301595688  1590184045248  1590184045248     1590184045248
# 21   0.052967652678489685  1590184045250  1590184045250     1590184045250
# 22   0.060321394354104996  1590184045253  1590184045253     1590184045253
# 23    0.08679430186748505  1590184045255  1590184045255     1590184045255
# 24    0.07398368418216705  1590184045258  1590184045258     1590184045258
# 25    0.07336408644914627  1590183636993  1590183636993     1590184042688
# 26    0.01317944098263979  1590183636994  1590183636994     1590184042688
# 27    0.03795541450381279  1590183636990  1590183636990     1590184042684
# 28   0.041253384202718735  1590183636991  1590183636991     1590184042686
# 29    0.03465631976723671  1590183636991  1590183636991     1590184042687
# 30    0.03795541450381279  1590183636990  1590183636990     1590184042685
# 31  0.0028981200885027647  1590183636991  1590183636991     1590184042685
#
#     stepMax  stepMin  stepCurrent
# 0      99.0     99.0         99.0
# 1       NaN     13.0         87.0
# 2      57.0     28.0         87.0
# 3       NaN      NaN          NaN
# 4      13.0      NaN         87.0
# 5       0.0     85.0         99.0
# 6       0.0     85.0         99.0
# 7       0.0     95.0         99.0
# 8       0.0     85.0         99.0
# 9      99.0     99.0         99.0
# 10     99.0     99.0         99.0
# 11     99.0     99.0         99.0
# 12     99.0     99.0         99.0
# 13     99.0     99.0         99.0
# 14     99.0     99.0         99.0
# 15     99.0     99.0         99.0
# 16     99.0     99.0         99.0
# 17     99.0     99.0         99.0
# 18     99.0     99.0         99.0
# 19     99.0     99.0         99.0
# 20     99.0     99.0         99.0
# 21     99.0     99.0         99.0
# 22     99.0     99.0         99.0
# 23     99.0     99.0         99.0
# 24     99.0     99.0         99.0
# 25      0.0     85.0         99.0
# 26      0.0     75.0         99.0
# 27      0.0     97.0         99.0
# 28      0.0     97.0         99.0
# 29      0.0     99.0         99.0
# 30      0.0     97.0         99.0
# 31      0.0     99.0         99.0

# %%
def bar_plot_per_person_from_metric(df):
    df = df.astype({"test_angle_error_degrees": float})
    best_model_row = df[df["test_angle_error_degrees"] == df["test_angle_error_degrees"].dropna().min()]
    metric_name_template = "test_angle_error_degrees_{}"
    
    people_ids = list(range(15))
    values = list()
    for person_id in people_ids:
        values.append(float(best_model_row[metric_name_template.format(person_id)]))
    
    plt.figure(figsize=(20, 10))
    sns.set(style="whitegrid")
    ax = sns.barplot(x=people_ids, y=values)
    ax.set_xlabel("Id osoby", fontsize=30)
    ax.set_ylabel("Błąd w stopniach", fontsize=30)
    ax.tick_params(axis='x', labelsize=20)
    ax.tick_params(axis='y', labelsize=20)
    
    plt.savefig(os.path.join(FOR_THESIS_DIR, 'both_eyes_error_per_person.png'))
    
    df_error_per_person = pd.DataFrame({"Id osoby": people_ids, "Błąd w stopniach": values})
    return df_error_per_person
